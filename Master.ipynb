# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.validation import check_is_fitted

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 200)

# %%
data_path = "dataset/H_MHAS_c2.dta" 
df = pd.read_stata(data_path)

# %%
column_names = list(df.columns.str.lower())

# %% [markdown]
# ## Feature Pre-Selection

# %%
target_columns = ['r1hosp1y',
 'r2hosp1y',
 'r3hosp1y',
 'r4hosp1y',
 'r5hosp1y']
target_columns_count = len(target_columns)

# %%
no_wave_columns = [
"unhhidnp",
"ragender",
]
no_wave_columns_count = len(no_wave_columns)

# %%
picked_columns = [

# Age at Interview (Months and Years)    
"r1agey",
"r2agey",
"r3agey",
"r4agey",
"r5agey",

# Self-Report of Health
"r1shlt",
"r2shlt",
"r3shlt",
"r4shlt",
"r5shlt",

# Doctor Diagnosed Health Problems: Ever Have Condition
"r1hibpe",
"r2hibpe",
"r3hibpe",
"r4hibpe",
"r5hibpe",
"r1diabe",
"r2diabe",
"r3diabe",
"r4diabe",
"r5diabe",
"r1cancre",
"r2cancre",
"r3cancre",
"r4cancre",
"r5cancre",
"r1respe",
"r2respe",
"r3respe",
"r4respe",
"r5respe",
"r1hrtatte",
"r2hrtatte",
"r3hrtatte",
"r4hrtatte",
"r5hrtatte",

"r4hearte",
"r5hearte",

"r1stroke",
"r2stroke",
"r3stroke",
"r4stroke",
"r5stroke",
"r1arthre",
"r2arthre",
"r3arthre",
"r4arthre",
"r5arthre",
"s5arthre",

# RwBMI is the respondent's self-reported body mass index
"r1bmi",
"r2bmi",
"r3bmi",
"r4bmi",
"r5bmi",

# Health Behaviors: Physical Activity or Exercise
"r1vigact",
"r2vigact",
"r3vigact",
"r4vigact",
"r5vigact",

# Health Behaviors: Smoking (Cigarettes)
"r1smokev",
"r2smokev",
"r3smokev",
"r4smokev",
"r5smokev",
"r1smoken",
"r2smoken",
"r3smoken",
"r4smoken",
"r5smoken",
"r1smokef",
"r2smokef",
"r3smokef",
"r4smokef",
"r5smokef",
"r1strtsmok",
"r2strtsmok",
"r3strtsmok",
"r4strtsmok",
"r5strtsmok",
"r1quitsmok",
"r2quitsmok",
"r3quitsmok",
"r4quitsmok",
"r5quitsmok",

# Health Behaviors: Preventive Care
"r1cholst",
"r2cholst",
"r3cholst",
"r4cholst",
"r5cholst",
"r3flusht",
"r4flusht",
"r5flusht",
"r1breast",
"r2breast",
"r3breast",
"r4breast",
"r5breast",
"r1mammog",
"r2mammog",
"r3mammog",
"r4mammog",
"r5mammog",
"r1papsm",
"r2papsm",
"r3papsm",
"r4papsm",
"r5papsm",
"r1prost",
"r2prost",
"r3prost",
"r4prost",
"r5prost",
]

# %%
screening = no_wave_columns + target_columns + picked_columns
print(screening)
# Work in a subset of the dataset
df_sub = df[screening]
df_sub.head(5)
# Out:
# ['unhhidnp', 'ragender', 'r1hosp1y', 'r2hosp1y', 'r3hosp1y', 'r4hosp1y', 'r5hosp1y', 'r1agey', 'r2agey', 'r3agey', 'r4agey', 'r5agey', 'r1shlt', 'r2shlt', 'r3shlt', 'r4shlt', 'r5shlt', 'r1hibpe', 'r2hibpe', 'r3hibpe', 'r4hibpe', 'r5hibpe', 'r1diabe', 'r2diabe', 'r3diabe', 'r4diabe', 'r5diabe', 'r1cancre', 'r2cancre', 'r3cancre', 'r4cancre', 'r5cancre', 'r1respe', 'r2respe', 'r3respe', 'r4respe', 'r5respe', 'r1hrtatte', 'r2hrtatte', 'r3hrtatte', 'r4hrtatte', 'r5hrtatte', 'r4hearte', 'r5hearte', 'r1stroke', 'r2stroke', 'r3stroke', 'r4stroke', 'r5stroke', 'r1arthre', 'r2arthre', 'r3arthre', 'r4arthre', 'r5arthre', 's5arthre', 'r1bmi', 'r2bmi', 'r3bmi', 'r4bmi', 'r5bmi', 'r1vigact', 'r2vigact', 'r3vigact', 'r4vigact', 'r5vigact', 'r1smokev', 'r2smokev', 'r3smokev', 'r4smokev', 'r5smokev', 'r1smoken', 'r2smoken', 'r3smoken', 'r4smoken', 'r5smoken', 'r1smokef', 'r2smokef', 'r3smokef', 'r4smokef', 'r5smokef', 'r1strtsmok', 'r2strtsmok', 'r3strtsmok', 'r4strtsmok', 'r5strtsmok', 'r1quitsmok', 'r2quitsmok', 'r3quitsmok', 'r4quitsmok', 'r5quitsmok', 'r1cholst', 'r2cholst', 'r3cholst', 'r4cholst', 'r5cholst', 'r3flusht', 'r4flusht', 'r5flusht', 'r1breast', 'r2breast', 'r3breast', 'r4breast', 'r5breast', 'r1mammog', 'r2mammog', 'r3mammog', 'r4mammog', 'r5mammog', 'r1papsm', 'r2papsm', 'r3papsm', 'r4papsm', 'r5papsm', 'r1prost', 'r2prost', 'r3prost', 'r4prost', 'r5prost']
#    unhhidnp ragender r1hosp1y r2hosp1y r3hosp1y r4hosp1y r5hosp1y  r1agey  \
# 0     110.0    1.Man    1.Yes     0.No     0.No      NaN      NaN    59.0
# 1     120.0  2.Woman     0.No     0.No     0.No     0.No     0.No    50.0
# 2     210.0    1.Man     0.No     0.No     0.No     0.No    1.Yes    69.0
# 3     220.0  2.Woman     0.No     0.No     0.No    1.Yes      NaN    48.0
# 4     310.0    1.Man     0.No     0.No     0.No     0.No     0.No    50.0
#
#    r2agey  r3agey  r4agey  r5agey  r1shlt       r2shlt  r3shlt  r4shlt  \
# 0    61.0    71.0     NaN     NaN  5.Poor  2.Very good  5.Poor     NaN
# 1    52.0    62.0    65.0    68.0  4.Fair       4.Fair  3.Good  3.Good
# 2    72.0    81.0    83.0    86.0  5.Poor          NaN  4.Fair  4.Fair
# 3    50.0    70.0    74.0     NaN  3.Good       4.Fair     NaN     NaN
# 4    53.0    62.0    65.0    68.0  3.Good       3.Good  4.Fair  3.Good
#
#    r5shlt r1hibpe r2hibpe r3hibpe r4hibpe r5hibpe r1diabe r2diabe r3diabe  \
# 0     NaN   1.yes   1.yes   1.yes     NaN     NaN    0.no    0.no    0.no
# 1  3.Good    0.no    0.no    0.no    0.no    0.no    0.no    0.no    0.no
# 2  3.Good    0.no    0.no    0.no    0.no   1.yes    0.no    0.no    0.no
# 3     NaN    0.no    0.no    0.no    0.no     NaN    0.no    0.no    0.no
# 4  3.Good    0.no    0.no    0.no    0.no    0.no    0.no    0.no   1.yes
#
#   r4diabe r5diabe r1cancre r2cancre r3cancre r4cancre r5cancre r1respe  \
# 0     NaN     NaN     0.no     0.no     0.no      NaN      NaN    0.no
# 1    0.no    0.no     0.no     0.no     0.no     0.no     0.no    0.no
# 2    0.no   1.yes     0.no     0.no     0.no     0.no     0.no    0.no
# 3    0.no     NaN     0.no     0.no     0.no     0.no      NaN    0.no
# 4   1.yes   1.yes     0.no     0.no     0.no     0.no     0.no    0.no
#
#   r2respe r3respe r4respe r5respe r1hrtatte r2hrtatte r3hrtatte r4hrtatte  \
# 0    0.no    0.no     NaN     NaN      0.no      0.no      0.no       NaN
# 1    0.no    0.no    0.no    0.no      0.no      0.no      0.no      0.no
# 2    0.no    0.no    0.no    0.no      0.no      0.no      0.no      0.no
# 3    0.no    0.no    0.no     NaN      0.no      0.no      0.no      0.no
# 4    0.no    0.no    0.no    0.no      0.no      0.no      0.no      0.no
#
#   r5hrtatte r4hearte r5hearte r1stroke r2stroke r3stroke r4stroke r5stroke  \
# 0       NaN      NaN      NaN     0.no     0.no     0.no      NaN      NaN
# 1      0.no     0.no     0.no     0.no     0.no     0.no     0.no     0.no
# 2      0.no     0.no     0.no     0.no     0.no     0.no     0.no     0.no
# 3       NaN     0.no      NaN     0.no     0.no     0.no     0.no      NaN
# 4      0.no     0.no     0.no     0.no     0.no     0.no     0.no     0.no
#
#   r1arthre r2arthre r3arthre r4arthre r5arthre s5arthre      r1bmi      r2bmi  \
# 0     0.no     0.no     0.no      NaN      NaN      NaN  29.068796        NaN
# 1     0.no     0.no     0.no     0.no     0.no      NaN        NaN  20.239502
# 2     0.no     0.no     0.no    1.yes    1.yes      NaN        NaN  39.262234
# 3     0.no     0.no     0.no     0.no      NaN      NaN        NaN  36.444443
# 4     0.no     0.no     0.no     0.no     0.no     0.no  26.812220  22.437674
#
#        r3bmi      r4bmi      r5bmi r1vigact r2vigact r3vigact r4vigact  \
# 0  28.719721        NaN        NaN    1.Yes    1.Yes     0.No      NaN
# 1        NaN  20.000000        NaN     0.No     0.No     0.No     0.No
# 2        NaN  26.709404        NaN     0.No      NaN    1.Yes    1.Yes
# 3  22.038568        NaN        NaN     0.No     0.No      NaN      NaN
# 4  28.400547  29.411762  25.605536     0.No    1.Yes     0.No    1.Yes
#
#   r5vigact r1smokev r2smokev r3smokev r4smokev r5smokev r1smoken r2smoken  \
# 0      NaN    1.Yes    1.Yes    1.Yes      NaN      NaN     0.No     0.No
# 1     0.No     0.No     0.No     0.No     0.No     0.No     0.No     0.No
# 2     0.No    1.Yes     0.No    1.Yes     0.No     0.No    1.Yes     0.No
# 3      NaN     0.No     0.No     0.No     0.No      NaN     0.No     0.No
# 4     0.No    1.Yes     0.No    1.Yes    1.Yes    1.Yes     0.No     0.No
#
#   r3smoken r4smoken r5smoken  r1smokef  r2smokef  r3smokef  r4smokef  \
# 0     0.No      NaN      NaN       0.0       0.0       0.0       NaN
# 1     0.No     0.No     0.No       0.0       0.0       0.0       0.0
# 2     0.No     0.No     0.No       1.0       0.0       0.0       0.0
# 3     0.No     0.No      NaN       0.0       0.0       0.0       0.0
# 4     0.No     0.No     0.No       0.0       0.0       0.0       0.0
#
#    r5smokef  r1strtsmok  r2strtsmok  r3strtsmok  r4strtsmok  r5strtsmok  \
# 0       NaN        14.0        14.0        14.0         NaN         NaN
# 1       0.0         NaN         NaN         NaN         NaN         NaN
# 2       0.0        14.0        14.0        14.0        14.0        14.0
# 3       NaN         NaN         NaN         NaN         NaN         NaN
# 4       0.0        18.0        18.0        18.0        18.0        18.0
#
#    r1quitsmok  r2quitsmok  r3quitsmok  r4quitsmok  r5quitsmok r1cholst  \
# 0        15.0        15.0        25.0         NaN         NaN    1.Yes
# 1         NaN         NaN         NaN         NaN         NaN    1.Yes
# 2         NaN         NaN        60.0        60.0        60.0     0.No
# 3         NaN         NaN         NaN         NaN         NaN     0.No
# 4         3.0         3.0        36.0        36.0        36.0     0.No
#
#   r2cholst r3cholst r4cholst r5cholst r3flusht r4flusht r5flusht r1breast  \
# 0    1.Yes    1.Yes      NaN      NaN     0.No      NaN      NaN      NaN
# 1    1.Yes     0.No     0.No    1.Yes     0.No     0.No     0.No    1.Yes
# 2      NaN    1.Yes    1.Yes    1.Yes     0.No    1.Yes     0.No      NaN
# 3    1.Yes      NaN    1.Yes      NaN      NaN     0.No      NaN     0.No
# 4    1.Yes    1.Yes    1.Yes    1.Yes    1.Yes    1.Yes    1.Yes      NaN
#
#   r2breast r3breast r4breast r5breast r1mammog r2mammog r3mammog r4mammog  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1    1.Yes    1.Yes    1.Yes     0.No     0.No     0.No     0.No     0.No
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3     0.No      NaN      NaN      NaN     0.No     0.No      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#   r5mammog r1papsm r2papsm r3papsm r4papsm r5papsm r1prost r2prost r3prost  \
# 0      NaN     NaN     NaN     NaN     NaN     NaN    0.No    0.No    0.No
# 1     0.No   1.Yes   1.Yes   1.Yes    0.No    0.No     NaN     NaN     NaN
# 2      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN    0.No
# 3      NaN    0.No   1.Yes     NaN     NaN     NaN     NaN     NaN     NaN
# 4      NaN     NaN     NaN     NaN     NaN     NaN   1.Yes   1.Yes   1.Yes
#
#   r4prost r5prost
# 0     NaN     NaN
# 1     NaN     NaN
# 2    0.No    0.No
# 3     NaN     NaN
# 4   1.Yes   1.Yes

# %%
# original name for columns with wave reference 
wave_vars_orig_name = screening[no_wave_columns_count:]
print(wave_vars_orig_name)
# Out:
# ['r1hosp1y', 'r2hosp1y', 'r3hosp1y', 'r4hosp1y', 'r5hosp1y', 'r1agey', 'r2agey', 'r3agey', 'r4agey', 'r5agey', 'r1shlt', 'r2shlt', 'r3shlt', 'r4shlt', 'r5shlt', 'r1hibpe', 'r2hibpe', 'r3hibpe', 'r4hibpe', 'r5hibpe', 'r1diabe', 'r2diabe', 'r3diabe', 'r4diabe', 'r5diabe', 'r1cancre', 'r2cancre', 'r3cancre', 'r4cancre', 'r5cancre', 'r1respe', 'r2respe', 'r3respe', 'r4respe', 'r5respe', 'r1hrtatte', 'r2hrtatte', 'r3hrtatte', 'r4hrtatte', 'r5hrtatte', 'r4hearte', 'r5hearte', 'r1stroke', 'r2stroke', 'r3stroke', 'r4stroke', 'r5stroke', 'r1arthre', 'r2arthre', 'r3arthre', 'r4arthre', 'r5arthre', 's5arthre', 'r1bmi', 'r2bmi', 'r3bmi', 'r4bmi', 'r5bmi', 'r1vigact', 'r2vigact', 'r3vigact', 'r4vigact', 'r5vigact', 'r1smokev', 'r2smokev', 'r3smokev', 'r4smokev', 'r5smokev', 'r1smoken', 'r2smoken', 'r3smoken', 'r4smoken', 'r5smoken', 'r1smokef', 'r2smokef', 'r3smokef', 'r4smokef', 'r5smokef', 'r1strtsmok', 'r2strtsmok', 'r3strtsmok', 'r4strtsmok', 'r5strtsmok', 'r1quitsmok', 'r2quitsmok', 'r3quitsmok', 'r4quitsmok', 'r5quitsmok', 'r1cholst', 'r2cholst', 'r3cholst', 'r4cholst', 'r5cholst', 'r3flusht', 'r4flusht', 'r5flusht', 'r1breast', 'r2breast', 'r3breast', 'r4breast', 'r5breast', 'r1mammog', 'r2mammog', 'r3mammog', 'r4mammog', 'r5mammog', 'r1papsm', 'r2papsm', 'r3papsm', 'r4papsm', 'r5papsm', 'r1prost', 'r2prost', 'r3prost', 'r4prost', 'r5prost']

# %%
# Remove the wave reference characters
from collections import OrderedDict
wave_vars_clean_name = list(OrderedDict.fromkeys([name[2:] for name in wave_vars_orig_name]))
wave_vars_clean_name_count = len(wave_vars_clean_name) 
print(wave_vars_clean_name_count, wave_vars_clean_name)
# Out:
# 24 ['hosp1y', 'agey', 'shlt', 'hibpe', 'diabe', 'cancre', 'respe', 'hrtatte', 'hearte', 'stroke', 'arthre', 'bmi', 'vigact', 'smokev', 'smoken', 'smokef', 'strtsmok', 'quitsmok', 'cholst', 'flusht', 'breast', 'mammog', 'papsm', 'prost']

# %%
# Decouple the wave as a column from the variables

from pprint import pprint

# Initialize an empty DataFrame with the desired final columns
# accumulated_df = pd.DataFrame(columns=final_columns)
accumulated_df = None

# Loop over the wave numbers
for wave in range(1, 6):
    # Create new column names for the current wave
    _names = [f"r{wave}{var}" for var in wave_vars_clean_name]
    wave_column_names = [name for name in _names if name in df_sub.columns] # Only keep valid column names
    # print(wave_column_names)
    column_mapping = {name: name[2:] for name in wave_column_names}  
    # print(column_mapping)

    # Select the necessary columns from the subset DataFrame and rename them
    wave_df = df_sub[no_wave_columns + wave_column_names].copy()
    wave_df = wave_df.rename(columns=column_mapping)

    # Insert the wave number as a new column
    wave_df.insert(0, "wave", wave)

    # Append the current wave's DataFrame to the accumulated DataFrame
    if accumulated_df is None:
        accumulated_df = wave_df.copy()
    else:
        accumulated_df = pd.concat([accumulated_df, wave_df])

# %%
accumulated_df.shape
# Out:
# (134195, 27)

# %%
drop_first_columns_count = 2 # wave and unhhidnp columns are not needed
# print(list(accumulated_df.columns))
# accumulated_df.iloc[:,drop_first_columns_count:].head()

# %%
# Prepare new clean dataset
df_clean = accumulated_df.iloc[:,drop_first_columns_count:].dropna(subset=["hosp1y"]).copy()
print(df_clean.shape)
# Swap ragender with hosp1y column to better readability
cols = list(df_clean)  # Get a list of column names
cols[0], cols[1] = cols[1], cols[0]  # Swap the first two names
df_clean = df_clean.reindex(columns=cols)  # Reindex the DataFrame with the new column order
# Out:
# (76353, 25)

# %% [markdown]
# ## Data Preprocessing

# %%
df_clean.head()
# Out:
#   hosp1y ragender  agey    shlt  hibpe diabe cancre respe hrtatte stroke  \
# 0  1.Yes    1.Man  59.0  5.Poor  1.yes  0.no   0.no  0.no    0.no   0.no
# 1   0.No  2.Woman  50.0  4.Fair   0.no  0.no   0.no  0.no    0.no   0.no
# 2   0.No    1.Man  69.0  5.Poor   0.no  0.no   0.no  0.no    0.no   0.no
# 3   0.No  2.Woman  48.0  3.Good   0.no  0.no   0.no  0.no    0.no   0.no
# 4   0.No    1.Man  50.0  3.Good   0.no  0.no   0.no  0.no    0.no   0.no
#
#   arthre        bmi vigact smokev smoken  smokef  strtsmok  quitsmok cholst  \
# 0   0.no  29.068796  1.Yes  1.Yes   0.No     0.0      14.0      15.0  1.Yes
# 1   0.no        NaN   0.No   0.No   0.No     0.0       NaN       NaN  1.Yes
# 2   0.no        NaN   0.No  1.Yes  1.Yes     1.0      14.0       NaN   0.No
# 3   0.no        NaN   0.No   0.No   0.No     0.0       NaN       NaN   0.No
# 4   0.no  26.812220   0.No  1.Yes   0.No     0.0      18.0       3.0   0.No
#
#   breast mammog  papsm  prost flusht hearte
# 0    NaN    NaN    NaN   0.No    NaN    NaN
# 1  1.Yes   0.No  1.Yes    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN
# 3   0.No   0.No   0.No    NaN    NaN    NaN
# 4    NaN    NaN    NaN  1.Yes    NaN    NaN

# %%
df_clean.isna().sum()
# Out:
# hosp1y          0
# ragender        0
# agey           34
# shlt         5727
# hibpe         578
# diabe         584
# cancre        536
# respe         518
# hrtatte       516
# stroke        493
# arthre        529
# bmi         13793
# vigact       5847
# smokev         44
# smoken         54
# smokef         72
# strtsmok    42317
# quitsmok    53011
# cholst       3703
# breast      35155
# mammog      35167
# papsm       35531
# prost       47743
# flusht      30310
# hearte      44562
# dtype: int64

# %%
# Drop some NaN records 
df_clean = df_clean.dropna(subset=["hosp1y","shlt"]).copy()
df_clean.shape
# Out:
# (70626, 25)

# %%
df_clean.dtypes
# Out:
# hosp1y      category
# ragender    category
# agey         float64
# shlt        category
# hibpe       category
# diabe       category
# cancre      category
# respe       category
# hrtatte     category
# stroke      category
# arthre      category
# bmi          float32
# vigact      category
# smokev      category
# smoken      category
# smokef       float64
# strtsmok     float64
# quitsmok     float64
# cholst      category
# breast      category
# mammog      category
# papsm       category
# prost       category
# flusht      category
# hearte      category
# dtype: object

# %%
# Prepare target value
df_clean.hosp1y = (df_clean.hosp1y == "1.Yes").astype(int)

# %%
df_clean.hosp1y.value_counts()
# Out:
# hosp1y
# 0    62564
# 1     8062
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

def split_dataset(df, target, random_state=1):
    df_full_train, df_test = train_test_split(df, test_size=.2, random_state=random_state)
    df_train, df_val = train_test_split(df_full_train, test_size=.2/.8, random_state=random_state)

    # Reset index and get y vectors
    df_full_train = df_full_train.reset_index(drop=True)
    df_train = df_train.reset_index(drop=True)
    df_val = df_val.reset_index(drop=True)
    df_test = df_test.reset_index(drop=True)

    y_train = df_train[target].values
    y_val = df_val[target].values
    y_test = df_test[target].values
            
    del df_train[target] 
    del df_val[target] 
    del df_test[target]

    return df_full_train, df_train, df_val, df_test, y_train, y_val, y_test

# %%
df_full_train, df_train, df_val, df_test, y_train, y_val, y_test = split_dataset(df_clean, "hosp1y")
len(df_train), len(df_val), len(df_test)
# Out:
# (42375, 14125, 14126)

# %% [markdown]
# # Preprocessing

# %%
df_full_train.shape
# Out:
# (56500, 25)

# %%
df_full_train.dtypes
# Out:
# hosp1y         int64
# ragender    category
# agey         float64
# shlt        category
# hibpe       category
# diabe       category
# cancre      category
# respe       category
# hrtatte     category
# stroke      category
# arthre      category
# bmi          float32
# vigact      category
# smokev      category
# smoken      category
# smokef       float64
# strtsmok     float64
# quitsmok     float64
# cholst      category
# breast      category
# mammog      category
# papsm       category
# prost       category
# flusht      category
# hearte      category
# dtype: object

# %%
for col in df_full_train.columns:
    print(col)
    print(list(df_full_train[col].unique()))
# Out:
# hosp1y
# [0, 1]
# ragender
# ['2.Woman', '1.Man']
# agey
# [56.0, 59.0, 69.0, 76.0, 68.0, 80.0, 62.0, 70.0, 53.0, 64.0, 77.0, 50.0, 54.0, 51.0, 78.0, 61.0, 79.0, 39.0, 55.0, 47.0, 45.0, 66.0, 60.0, 58.0, 63.0, 57.0, 65.0, 49.0, 90.0, 48.0, 83.0, 72.0, 75.0, 67.0, 92.0, 35.0, 43.0, 74.0, 73.0, 52.0, 82.0, 46.0, 84.0, 89.0, 71.0, 44.0, 34.0, 28.0, nan, 42.0, 38.0, 81.0, 86.0, 31.0, 87.0, 91.0, 85.0, 88.0, 40.0, 97.0, 96.0, 94.0, 29.0, 98.0, 112.0, 41.0, 32.0, 27.0, 37.0, 21.0, 93.0, 25.0, 107.0, 110.0, 102.0, 30.0, 36.0, 99.0, 95.0, 33.0, 19.0, 105.0, 26.0, 22.0, 24.0, 18.0, 101.0, 100.0, 106.0, 16.0, 20.0, 23.0]
# shlt
# ['3.Good', '4.Fair', '5.Poor', '2.Very good', '1.Excellent']
# hibpe
# ['1.yes', '0.no', nan]
# diabe
# ['0.no', '1.yes', nan]
# cancre
# ['0.no', nan, '1.yes']
# respe
# ['0.no', '1.yes', nan]
# hrtatte
# ['0.no', '1.yes', nan]
# stroke
# ['0.no', nan, '1.yes']
# arthre
# ['0.no', '1.yes', nan]
# bmi
# [20.342798, 26.395803, nan, 26.037493, 41.09139, 24.977043, 31.202566, 31.640625, 26.171875, 25.402817, 29.136318, 27.61341, 23.805403, 25.78125, 21.453285, 28.57143, 16.620499, 27.555555, 29.996716, 29.7339, 27.398174, 24.801588, 25.826447, 38.567493, 33.77778, 20.568806, 35.714287, 26.196188, 29.054752, 24.221453, 19.11111, 21.066744, 22.491348, 22.832878, 20.811655, 25.065748, 33.057854, 26.953125, 20.20202, 28.0, 26.038782, 37.044746, 24.913494, 26.377897, 26.222221, 25.28257, 32.86137, 28.25097, 20.700817, 27.239223, 26.813591, 23.875116, 25.390625, 26.314636, 27.392256, 26.666666, 24.092972, 27.53123, 51.11111, 26.346495, 32.0, 28.305996, 34.666668, 28.303852, 29.6875, 18.666666, 40.03673, 20.761244, 26.5625, 19.53125, 30.46875, 31.141867, 20.3125, 26.643597, 24.21875, 23.337683, 29.721079, 24.111507, 27.774422, 24.056934, 21.55102, 27.141582, 23.999458, 35.755955, 23.828125, 28.537453, 28.444445, 17.777779, 23.011179, 24.489796, 27.434841, 32.87197, 37.804077, 33.648453, 29.777779, 20.284798, 25.344353, 21.258505, 35.204304, 28.133657, 29.154518, 27.734375, 20.069202, 33.308983, 34.92768, 30.844414, 31.861628, 18.289894, 27.688778, 30.120483, 28.672628, 34.602074, 27.47563, 24.444445, 25.951555, 28.685146, 27.54821, 24.767567, 19.312954, 30.427197, 24.141521, 25.0, 41.207077, 28.959, 31.25, 23.507807, 23.4375, 31.633717, 25.21736, 29.387754, 22.589552, 29.296875, 32.82414, 32.4622, 20.661158, 29.761906, 29.048658, 27.766207, 22.862535, 37.59238, 30.487806, 25.910685, 24.256836, 22.65625, 27.09925, 21.829952, 25.887575, 25.876059, 31.377989, 27.777779, 29.86496, 20.077335, 23.555555, 25.333334, 22.773188, 26.026175, 26.83518, 17.745846, 24.088223, 28.373701, 24.341757, 43.146202, 25.476662, 30.477968, 26.218822, 26.29849, 28.125, 26.020409, 26.446281, 38.671875, 33.333332, 34.04903, 27.293222, 29.218407, 25.180786, 24.064047, 23.510204, 25.566107, 40.858833, 20.545694, 20.429417, 23.388685, 29.372398, 23.335466, 28.398716, 34.547348, 24.609375, 28.507523, 21.777779, 21.227888, 29.674944, 18.376825, 29.488703, 25.945486, 22.222221, 21.192743, 22.265625, 29.357523, 29.407787, 34.105854, 27.055153, 27.335638, 26.12245, 29.333334, 34.256054, 28.763973, 29.000595, 34.367916, 25.788536, 33.203125, 19.477148, 34.131115, 22.82688, 23.530365, 22.666666, 28.88889, 24.84098, 33.331833, 21.484375, 26.854406, 21.40309, 27.7671, 28.194284, 27.68166, 30.859375, 23.11111, 28.691748, 26.48554, 30.853209, 22.829964, 30.116215, 32.11195, 22.031725, 30.486658, 31.91931, 28.946098, 27.91552, 25.777779, 24.998903, 25.39343, 21.604105, 27.772268, 29.968784, 30.080057, 31.624222, 24.02381, 28.720085, 30.795847, 35.599857, 23.624447, 27.755102, 19.433014, 26.63892, 26.159332, 23.108433, 26.989618, 27.34375, 64.96975, 23.529411, 28.90625, 19.814053, 30.246916, 29.031792, 26.838646, 35.9375, 21.750196, 26.365602, 27.968018, 23.781212, 26.222687, 29.757586, 29.7442, 24.691359, 37.46098, 28.061829, 21.875, 30.297785, 23.889463, 23.939482, 24.776796, 26.634956, 17.959183, 32.27079, 31.912226, 25.510206, 32.007317, 30.062101, 32.04588, 24.973988, 27.887619, 27.852009, 28.934069, 32.818073, 21.333334, 26.619343, 27.587324, 31.245237, 27.471386, 26.573132, 31.11111, 31.980541, 27.6398, 31.887756, 23.711845, 36.6782, 30.11028, 41.16247, 30.330215, 31.955923, 24.675499, 23.45679, 29.432135, 43.262295, 24.654835, 17.728533, 22.47659, 36.88889, 26.058355, 32.28306, 24.005487, 31.163435, 23.068052, 29.402275, 24.034609, 19.834711, 30.421848, 32.421875, 25.864513, 24.835762, 25.765715, 17.941818, 36.52301, 24.567472, 23.725288, 35.11111, 30.693878, 18.378492, 36.289738, 24.535124, 39.11111, 25.96454, 32.950684, 35.749508, 32.83098, 32.34245, 31.12268, 32.323235, 30.407629, 29.384758, 33.760387, 27.1809, 28.721123, 24.594906, 30.824831, 28.3771, 30.7174, 24.238228, 28.042816, 25.249338, 39.819946, 35.15625, 26.106562, 28.734694, 25.208084, 32.65306, 20.715693, 21.641275, 32.368874, 41.322315, 24.557755, 37.265152, 27.551022, 19.377161, 24.464602, 24.88889, 22. ...
# vigact
# ['0.No', '1.Yes', nan]
# smokev
# ['0.No', '1.Yes', nan]
# smoken
# ['0.No', '1.Yes', nan]
# smokef
# [0.0, 1.0, 20.0, 2.0, 10.0, 5.0, 7.0, 3.0, 18.0, 15.0, 8.0, 60.0, 4.0, 6.0, 40.0, nan, 24.0, 11.0, 30.0, 12.0, 14.0, 9.0, 25.0, 32.0, 100.0, 88.0, 36.0, 22.0, 35.0, 16.0, 23.0, 13.0, 87.0, 48.0, 17.0, 99.0, 27.0, 26.0, 19.0, 50.0, 38.0]
# strtsmok
# [nan, 21.0, 11.0, 19.0, 20.0, 22.0, 14.0, 16.0, 17.0, 15.0, 12.0, 23.0, 10.0, 18.0, 45.0, 30.0, 28.0, 40.0, 42.0, 9.0, 36.0, 50.0, 25.0, 27.0, 35.0, 13.0, 29.0, 31.0, 26.0, 24.0, 34.0, 48.0, 75.0, 44.0, 43.0, 55.0, 39.0, 53.0, 33.0, 32.0, 54.0, 6.0, 62.0, 51.0, 58.0, 52.0, 8.0, 49.0, 47.0, 41.0, 37.0, 38.0, 60.0, 64.0, 61.0, 56.0, 63.0, 46.0, 1.0, 68.0, 57.0, 77.0, 7.0, 59.0, 69.0, 76.0, 66.0, 67.0, 80.0, 78.0, 65.0, 70.0, 82.0, 84.0, 73.0, 2.0, 5.0, 83.0, 71.0, 74.0, 85.0]
# quitsmok
# [nan, 4.0, 42.0, 30.0, 48.0, 47.0, 41.0, 19.0, 25.0, 1.0, 36.0, 8.0, 60.0, 15.0, 18.0, 23.0, 2.0, 10.0, 35.0, 45.0, 17.0, 20.0, 7.0, 43.0, 12.0, 57.0, 28.0, 3.0, 24.0, 44.0, 31.0, 58.0, 9.0, 55.0, 40.0, 73.0, 34.0, 49.0, 53.0, 50.0, 39.0, 11.0, 6.0, 37.0, 54.0, 22.0, 52.0, 51.0, 64.0, 59.0, 67.0, 26.0, 21.0, 13.0, 68.0, 56.0, 33.0, 38.0, 66.0, 62.0, 14.0, 16.0, 29.0, 77.0, 5.0, 79.0, 69.0, 46.0, 65.0, 27.0, 61.0, 72.0, 70.0, 75.0, 78.0, 32.0, 74.0, 71.0, 85.0, 63.0, 81.0, 76.0, 93.0, 80.0, 82.0, 87.0, 88.0, 83.0, 89.0, 84.0, 99.0]
# cholst
# ['1.Yes', '0.No', nan]
# breast
# ['1.Yes', nan, '0.No']
# mammog
# ['1.Yes', nan, '0.No']
# papsm
# ['1.Yes', nan, '0.No']
# prost
# [nan, '0.No', '1.Yes']
# flusht
# ['1.Yes', nan, '0.No']
# hearte
# ['0.no', nan, '1.yes']

# %%
numerical = list(df_full_train.dtypes[df_full_train.dtypes.ne("category")].index)[1:] # using 1: to skip hosp1y
numerical
# Out:
# ['agey', 'bmi', 'smokef', 'strtsmok', 'quitsmok']

# %%
categorical = [col for col in list(df_full_train.dtypes.index) if col not in numerical][1:] # using 1: to skip hosp1y
categorical
# Out:
# ['ragender',
#  'shlt',
#  'hibpe',
#  'diabe',
#  'cancre',
#  'respe',
#  'hrtatte',
#  'stroke',
#  'arthre',
#  'vigact',
#  'smokev',
#  'smoken',
#  'cholst',
#  'breast',
#  'mammog',
#  'papsm',
#  'prost',
#  'flusht',
#  'hearte']

# %%
df_full_train[numerical]
# Out:
#        agey        bmi  smokef  strtsmok  quitsmok
# 0      56.0  20.342798     0.0       NaN       NaN
# 1      59.0  26.395803     1.0      21.0       NaN
# 2      56.0        NaN     0.0      11.0       NaN
# 3      69.0        NaN     0.0       NaN       NaN
# 4      76.0  26.037493     0.0       NaN       NaN
# ...     ...        ...     ...       ...       ...
# 56495  71.0  24.557755     0.0       NaN       NaN
# 56496  67.0  30.818542    10.0      50.0       NaN
# 56497  75.0  22.206331     6.0      16.0       NaN
# 56498  62.0  24.801588     0.0       NaN       NaN
# 56499  59.0        NaN    10.0      20.0       NaN
#
# [56500 rows x 5 columns]

# %%
df_full_train[numerical].corrwith(df_full_train.hosp1y)
# Out:
# agey        0.072868
# bmi        -0.000478
# smokef     -0.029393
# strtsmok   -0.001650
# quitsmok    0.040857
# dtype: float64

# %%
for col in categorical:
    print("\t", col, "->", df_full_train[col].unique())
# Out:
# 	 ragender -> ['2.Woman', '1.Man']
# Categories (2, object): ['1.Man' < '2.Woman']
# 	 shlt -> ['3.Good', '4.Fair', '5.Poor', '2.Very good', '1.Excellent']
# Categories (5, object): ['1.Excellent' < '2.Very good' < '3.Good' < '4.Fair' < '5.Poor']
# 	 hibpe -> ['1.yes', '0.no', NaN]
# Categories (2, object): ['0.no' < '1.yes']
# 	 diabe -> ['0.no', '1.yes', NaN]
# Categories (2, object): ['0.no' < '1.yes']
# 	 cancre -> ['0.no', NaN, '1.yes']
# Categories (2, object): ['0.no' < '1.yes']
# 	 respe -> ['0.no', '1.yes', NaN]
# Categories (2, object): ['0.no' < '1.yes']
# 	 hrtatte -> ['0.no', '1.yes', NaN]
# Categories (2, object): ['0.no' < '1.yes']
# 	 stroke -> ['0.no', NaN, '1.yes']
# Categories (2, object): ['0.no' < '1.yes']
# 	 arthre -> ['0.no', '1.yes', NaN]
# Categories (2, object): ['0.no' < '1.yes']
# 	 vigact -> ['0.No', '1.Yes', NaN]
# Categories (2, object): ['0.No' < '1.Yes']
# 	 smokev -> ['0.No', '1.Yes', NaN]
# Categories (2, object): ['0.No' < '1.Yes']
# 	 smoken -> ['0.No', '1.Yes', NaN]
# Categories (2, object): ['0.No' < '1.Yes']
# 	 cholst -> ['1.Yes', '0.No', NaN]
# Categories (2, object): ['0.No' < '1.Yes']
# 	 breast -> ['1.Yes', NaN, '0.No']
# Categories (2, object): ['0.No' < '1.Yes']
# 	 mammog -> ['1.Yes', NaN, '0.No']
# Categories (2, object): ['0.No' < '1.Yes']
# 	 papsm -> ['1.Yes', NaN, '0.No']
# Categories (2, object): ['0.No' < '1.Yes']
# 	 prost -> [NaN, '0.No', '1.Yes']
# Categories (2, object): ['0.No' < '1.Yes']
# 	 flusht -> ['1.Yes', NaN, '0.No']
# Categories (2, object): ['0.No' < '1.Yes']
# 	 hearte -> ['0.no', NaN, '1.yes']
# Categories (2, object): ['0.no' < '1.yes']

# %%
enc_mapper = {"numerical": numerical, "categorical": categorical}

# %%
enc_mapper["categorical"], enc_mapper["numerical"]
# Out:
# (['ragender',
#   'shlt',
#   'hibpe',
#   'diabe',
#   'cancre',
#   'respe',
#   'hrtatte',
#   'stroke',
#   'arthre',
#   'vigact',
#   'smokev',
#   'smoken',
#   'cholst',
#   'breast',
#   'mammog',
#   'papsm',
#   'prost',
#   'flusht',
#   'hearte'],
#  ['agey', 'bmi', 'smokef', 'strtsmok', 'quitsmok'])

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder


def preprocess_data(df_train, df_val, df_test, enc_mapper):
    # Print shape of input data
    print("Input train data shape: ", df_train.shape)
    print("Input val data shape: ", df_val.shape)
    print("Input test data shape: ", df_test.shape, "\n")

    # Make a copy of the dataframes
    working_train_df = df_train.copy()
    working_val_df = df_val.copy()
    working_test_df = df_test.copy()

    # Group cols by type
    categorical = enc_mapper["categorical"]
    numerical = enc_mapper["numerical"]

    X_train = working_train_df[numerical].values
    X_val = working_val_df[numerical].values
    X_test = working_test_df[numerical].values

    ohe = OneHotEncoder()

    # Fit on the training data
    ohe.fit(working_train_df[categorical])

    # Transform train, val and test data
    X_train = np.concatenate((X_train, ohe.transform(working_train_df[categorical]).todense()), axis=1)
    X_val = np.concatenate((X_val, ohe.transform(working_val_df[categorical]).todense()), axis=1)
    X_test = np.concatenate((X_test, ohe.transform(working_test_df[categorical]).todense()), axis=1)

    X_train = np.asarray(X_train)
    X_val = np.asarray(X_val)
    X_test = np.asarray(X_test)
    
    imputer = SimpleImputer(strategy='median')
    imputer.fit(X_train)

    X_train = imputer.transform(X_train)
    X_val = imputer.transform(X_val)
    X_test = imputer.transform(X_test)

    scaler = MinMaxScaler(feature_range = (0, 1))
    scaler.fit(X_train)

    X_train = scaler.transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    return X_train, X_val, X_test

# %% [markdown]
# ## Preprocessing

# %%
X_train, X_val, X_test = preprocess_data(df_train, df_val, df_test, enc_mapper)
# Out:
# Input train data shape:  (42375, 24)
# Input val data shape:  (14125, 24)
# Input test data shape:  (14126, 24)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# %%time

log_reg = None
log_reg = LogisticRegression(C=0.0001, solver='liblinear', max_iter=1000)
log_reg.fit(X_train, y_train)
# Out:
# CPU times: user 126 ms, sys: 196 µs, total: 126 ms
# Wall time: 124 ms
# LogisticRegression(C=0.0001, max_iter=1000, solver='liblinear')

# %%
# Train data predictions (class 1)
log_reg_train = log_reg.predict_proba(X_train)[:, 1]

# Validation data predictions (class 1)
log_reg_val = log_reg.predict_proba(X_val)[:, 1]

# %%
from sklearn.metrics import roc_auc_score

# Train ROC AUC Score
roc_auc_train = roc_auc_score(y_true=y_train, y_score=log_reg_train)
print(f"Train ROC AUC Score: {roc_auc_train:.4f}")

# Validation ROC AUC Score
roc_auc_val = roc_auc_score(y_true=y_val, y_score=log_reg_val)
print(f"Validation ROC AUC Score: {roc_auc_val:.4f}")
# Out:
# Train ROC AUC Score: 0.6793
# Validation ROC AUC Score: 0.6944

# %% [markdown]
# ## Random Forest

# %%
# %%time

rf = RandomForestClassifier(n_estimators = 100, random_state = 47, verbose = 1, n_jobs = -1)
rf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.7s
# CPU times: user 10.7 s, sys: 107 ms, total: 10.8 s
# Wall time: 1.77 s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    1.7s finished
# RandomForestClassifier(n_jobs=-1, random_state=47, verbose=1)

# %%
# Train data predictions (class 1)
rf_pred_train = rf.predict_proba(X_train)[:, 1]

# Validation data predictions (class 1)
rf_pred_val = rf.predict_proba(X_val)[:, 1]
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
roc_auc_train = roc_auc_score(y_true=y_train, y_score=rf_pred_train)
print(f"Train ROC AUC Score: {roc_auc_train:.4f}")

# Validation ROC AUC Score
roc_auc_val = roc_auc_score(y_true=y_val, y_score=rf_pred_val)
print(f"Validation ROC AUC Score: {roc_auc_val:.4f}")
# Out:
# Train ROC AUC Score: 1.0000
# Validation ROC AUC Score: 0.6655
